# %% [markdown]
# <a href="https://colab.research.google.com/github/arianagar77/Probabilidad/blob/main/Pract1_Ari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sympy

def area(radio):
    return sympy.pi * (radio ** 2)

# %%
import random

moneda_lados = ["aguila", "sol"]

def lanzar_moneda():
    return random.choice(moneda_lados)

lanzar_moneda()
# Out:
# 'sol'

# %%
import random

dado_lados = ["1", "2","3", "4", "5", "6"]

def lanzar_dado():
    return random.choice(dado_lados)

lanzar_dado()
# Out:
# '2'
